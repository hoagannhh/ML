# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from PIL import Image
from sklearn.preprocessing import OrdinalEncoder
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import Lasso

# %% [markdown]
# # **Dataset**

# %%
df = pd.read_csv("../data/winequality-red.csv")
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %% [markdown]
# # **PHÂN TÍCH DỮ LIỆU (EDA)**

# %% [markdown]
# ## Tổng quan dữ liệu

# %%
# Kích thước dataset
row, column = df.shape
print(f"Row: {row}, Column: {column}")
# Out:
# Row: 1599, Column: 12

# %%
# Thông tin kiểu dữ liệu, null
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %%
# Kiểm tra giá trị thiếu (null)
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %%
# Thống kê cơ bản các cột số
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %%
# Kiểm tra dữ liệu có trùng lặp
df.duplicated().any()
# Out:
# np.True_

# %%
#loại bỏ trùng lặp
df = df.drop_duplicates()
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 5            7.4              0.66         0.00             1.8      0.075
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 5                 13.0                  40.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
# Kích thước dataset
row, column = df.shape
print(f"Row: {row}, Column: {column}")
# Out:
# Row: 1359, Column: 12

# %%
df.describe().T.style.background_gradient()
# Out:
# <style type="text/css">
# #T_83976_row0_col0, #T_83976_row1_col0, #T_83976_row1_col7, #T_83976_row2_col0, #T_83976_row2_col3, #T_83976_row2_col4, #T_83976_row2_col7, #T_83976_row3_col0, #T_83976_row4_col0, #T_83976_row4_col1, #T_83976_row4_col2, #T_83976_row4_col3, #T_83976_row4_col4, #T_83976_row4_col5, #T_83976_row4_col6, #T_83976_row4_col7, #T_83976_row5_col0, #T_83976_row6_col0, #T_83976_row7_col0, #T_83976_row7_col2, #T_83976_row7_col7, #T_83976_row8_col0, #T_83976_row9_col0, #T_83976_row10_col0, #T_83976_row11_col0 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_83976_row0_col1 {
#   background-color: #e0deed;
#   color: #000000;
# }
# #T_83976_row0_col2, #T_83976_row0_col7, #T_83976_row3_col1, #T_83976_row3_col5, #T_83976_row3_col7, #T_83976_row8_col6 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_83976_row0_col3 {
#   background-color: #5c9fc9;
#   color: #f1f1f1;
# }
# #T_83976_row0_col4 {
#   background-color: #b8c6e0;
#   color: #000000;
# }
# ...

# %% [markdown]
# **Nhân xét:**
#
# *   Kích thước dữ liệu là (1599, 12).
#
# *   Tất cả cột là kiểu số. Cột cuối là phân loại.
#
# *   Không có cột nào thiếu dữ liệu.
#
# *   quality là nhãn của dữ liệu.
#
# *   Các cột có sự phân tán cao là: free sulfur dioxide, total sulfur dioxide.
#
# *   Dữ liệu có sự trùng lặp (drop). Kích thước dữ liệu sau khi xử lý trùng lặp (1359, 12)
